# %% [markdown]
# # Analysis report of ABC Company for the duration 2022-23

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading preprocessed dataset

# %%
df = pd.read_excel("C://Users//navs9//Downloads//myexcel.xlsx")
df
# Out:
#        Player name            Team  Jersy number Player position  Age
# 0    Avery Bradley  Boston Celtics             0              PG   25  \
# 1      Jae Crowder  Boston Celtics            99              SF   25
# 2     John Holland  Boston Celtics            30              SG   27
# 3      R.J. Hunter  Boston Celtics            28              SG   22
# 4    Jonas Jerebko  Boston Celtics             8              PF   29
# ..             ...             ...           ...             ...  ...
# 453   Shelvin Mack       Utah Jazz             8              PG   26
# 454      Raul Neto       Utah Jazz            25              PG   24
# 455   Tibor Pleiss       Utah Jazz            21               C   26
# 456    Jeff Withey       Utah Jazz            24               C   26
# 457       Priyanka       Utah Jazz            34               C   25
#
#      Height in cm  Weight in lbs   College of study  Salary in $
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Player name       458 non-null    object
#  1   Team              458 non-null    object
#  2   Jersy number      458 non-null    int64
#  3   Player position   458 non-null    object
#  4   Age               458 non-null    int64
#  5   Height in cm      458 non-null    int64
#  6   Weight in lbs     458 non-null    int64
#  7   College of study  458 non-null    object
#  8   Salary in $       458 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 32.3+ KB

# %%
df.dtypes
# Out:
# Player name         object
# Team                object
# Jersy number         int64
# Player position     object
# Age                  int64
# Height in cm         int64
# Weight in lbs        int64
# College of study    object
# Salary in $          int64
# dtype: object

# %% [markdown]
# ### Analysing the data

# %%
# Qn.1: How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
#Counting
count = df["Team"].value_counts()
print("No of employees in each team:\n",count)
# Out:
# No of employees in each team:
#  Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
#Visualizing
plt.figure(figsize=(60,30),dpi=100)
x=count.index
y=count.values
plt.bar(x, y, color='green',width=0.5)
plt.xticks(fontsize=35)
plt.xticks(rotation=90)
plt.yticks(fontsize=35)
plt.title('Number of employees in each team',size=65)
plt.xlabel('Team',size=45)
plt.ylabel('Number of employees',size=45)
plt.show()

# %%
#Total number of teams.
print("Total number of teams =",len(count))
# Out:
# Total number of teams = 30

# %%
#Percentage split of employees by each team.
percentage_split = count/ len(df) * 100
print("The percentage split of employees with respect to the total employees:\n",percentage_split)
# Out:
# The percentage split of employees with respect to the total employees:
#  Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# ...

# %%
#Visualizing
plt.figure(figsize=(60,30),dpi=100)
x=percentage_split.index
y=percentage_split.values
plt.bar(x, y, color=['green','red'],width=0.5)
plt.xticks(fontsize=35)
plt.xticks(rotation=90)
plt.yticks(fontsize=35)
plt.title('Percentage split of employees in each team',size=65)
plt.xlabel('Team',size=45)
plt.ylabel('Percentage',size=45)
plt.show()

# %%
# Qn.2: Segregate the employees w.r.t different positions.

# %%
#position grouping
Position_data = df.groupby(['Player position','Player name']).sum()
Position_data
# Out:
#                                                  Team  Jersy number  Age
# Player position Player name
# C               Al Horford              Atlanta Hawks            15   30  \
#                 Al Jefferson        Charlotte Hornets            25   31
#                 Alan Williams            Phoenix Suns            15   23
#                 Alex Len                 Phoenix Suns            21   22
#                 Alexis Ajinca    New Orleans Pelicans            42   28
# ...                                               ...           ...  ...
# SG              Tyreke Evans     New Orleans Pelicans             1   26
#                 Victor Oladipo          Orlando Magic             5   24
#                 Vince Carter        Memphis Grizzlies            15   39
#                 Wayne Ellington         Brooklyn Nets            21   28
#                 Wesley Matthews      Dallas Mavericks            23   29
#
#                                  Height in cm  Weight in lbs
# ...

# %%
# Count of employees working in each postions,
position_count=df['Player position'].value_counts()
print("Number of players in different positions are:")
position_count
# Out:
# Number of players in different positions are:
# Player position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
#visualizing the results.
plt.bar(position_count.index,position_count.values,color='green')
plt.xlabel("Player position")
plt.ylabel("Number of employees/players")
plt.title("Employee Position Distribution")
# Out:
# Text(0.5, 1.0, 'Employee Position Distribution')

# %%
# Qn.3: Find from which age group most of the employees belong to.

# %%
#grouping
age_group = df["Age"].value_counts()
print("Different age group of players are:")
age_group
# Out:
# Different age group of players are:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
#which age group most of the employees
age_max=age_group.head(1).index
print("Most of the employees belong to age group of",age_max[0])
# Out:
# Most of the employees belong to age group of 24

# %%
#visualizing
plt.figure(figsize=(22,22))
plt.pie(age_group,labels=age_group.index,autopct='%0.2f%%',radius=1)
plt.title("Distribution of players by age group",size=35)
plt.show()

# %%
# Qn.4: Find out under which team and position, spending in terms of salary is high.

# %%
team_salary=df.groupby(['Team','Player position'])['Salary in $'].sum()
team_salary
# Out:
# Team                Player position
# Atlanta Hawks       C                  22756250
#                     PF                 23952268
#                     PG                  9763400
#                     SF                  6000000
#                     SG                 10431032
#                                          ...
# Washington Wizards  C                  24490429
#                     PF                 11300000
#                     PG                 18022415
#                     SF                 11158800
#                     SG                 11356992
# Name: Salary in $, Length: 149, dtype: int64

# %%
Highest_salary = team_salary.idxmax()
print("Highest salary is in:",Highest_salary)
print("The {} team and {} player position is spending high in terms of salary!".format (Highest_salary[0],Highest_salary[1]))
# Out:
# Highest salary is in: ('Los Angeles Lakers', 'SF')
# The Los Angeles Lakers team and SF player position is spending high in terms of salary!

# %%
# Qn.5: Find if there is any correlation between age and salary , represent it visually.

# %%
#Finding correlation
correlation=df['Age'].corr(df["Salary in $"])
print("The correlation between age and salary is",correlation)

#Scatter plot visualization
age=df['Age']
salary=df['Salary in $']
plt.xlabel("Age")
plt.ylabel("Salary in $")
plt.title("Age v/s Salary")
sns.scatterplot(x=age,y=salary,hue=age,palette='viridis')
plt.show()
# Out:
# The correlation between age and salary is 0.205009604535111

# %% [markdown]
# #### From the above scatter plot even though we can observe no linear relation ship between age and salary of players but it is evident from the plot that as age increases some players are having high salary may be due to their experience in the field.

# %% [markdown]
# ## The End
